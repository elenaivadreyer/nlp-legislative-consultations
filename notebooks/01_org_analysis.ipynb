# %% [markdown]
# # Organization-Level Analysis
#
# This notebook analyzes the structure and characteristics of stakeholder submissions during the consultation process for the Geothermiebeschleunigungsgesetz.

# %% [markdown]
# ## 1. Data Loading
#
# Load the consultation data containing legislative drafts and stakeholder comments.

# %%
import pandas as pd

EXCEL_PATH = "../data/geothermie_gesetz_kommentare.xlsx"
SHEET_NAME = "Gesetz + Kommentare"

df = pd.read_excel(EXCEL_PATH, sheet_name=SHEET_NAME)
df.head()
# Out:
#    Artikel                     Typ  Paragraph  Absatz  Gliederungspunkt_Nr  \
# 0        1  Allgemeine Anmerkungen         -1       0                  NaN
# 1        1        Paragraph/Absatz          1       0                  NaN
# 2        1        Paragraph/Absatz          2       0                  NaN
# 3        1        Paragraph/Absatz          3       0                  NaN
# 4        1        Paragraph/Absatz          4       0                  NaN
#
#                          Gesetzestext_Entwurf_1_0307  \
# 0                                                NaN
# 1  Zweck und Ziel des Gesetzes\nZweck dieses Gese...
# 2  Anwendungsbereich\nDieses Gesetz ist anzuwende...
# 3  Begriffsbestimmungen\nIm Sinne dieses Gesetzes...
# 4  Überragendes öffentliches Interesse\nDie Erric...
#
#                          Gesetzestext_Entwurf_2_1508  \
# 0                                                NaN
# 1  Zweck und Ziel des Gesetzes\nZweck dieses Gese...
# 2  Anwendungsbereich\nDieses Gesetz ist anzuwende...
# 3  Begriffsbestimmungen\nIm Sinne dieses Gesetzes...
# 4  Überragendes öffentliches Interesse\nDie Erric...
#
#                          Gesetzestext_Entwurf_3_0110  \
# 0                                                NaN
# 1  Zweck und Ziel des Gesetzes\nZweck dieses Gese...
# 2  Anwendungsbereich\nDieses Gesetz ist anzuwende...
# 3  Begriffsbestimmungen\nIm Sinne dieses Gesetzes...
# 4  Überragendes öffentliches Interesse\nDie Erric...
#
#                          Gesetzestext_Entwurf_4_0312  \
# 0                                                NaN
# 1  Zweck und Ziel des Gesetzes\nZweck dieses Gese...
# 2  Anwendungsbereich\nDieses Gesetz ist anzuwende...
# 3  Begriffsbestimmungen\nIm Sinne dieses Gesetzes...
# 4  Überragendes öffentliches Interesse\nDie Erric...
#
#                                                Org_2  ... Org_24 Org_25  \
# 0  Der Beschleunigungseffekt des GeoBG erscheint ...  ...    NaN    NaN
# 1                                                NaN  ...    NaN    NaN
# 2                                                NaN  ...    NaN    NaN
# 3                                                NaN  ...    NaN    NaN
# 4                                                NaN  ...    NaN    NaN
#
#   Org_26 Org_27                                             Org_28  \
# 0    NaN    NaN  Grundsätzlich ist ein Mehr an Geothermie, Sole...
# 1    NaN    NaN                                                NaN
# 2    NaN    NaN                                                NaN
# 3    NaN    NaN                                                NaN
# 4    NaN    NaN                                                NaN
#
#                                               Org_29    Org_30 Org_31 Org_32  \
# 0  Die Dekarbonisierung der Wärmeversorgung ist e...  s.o. § 1    NaN    NaN
# 1                                                NaN       NaN    NaN    NaN
# 2                                                NaN       NaN    NaN    NaN
# 3                                                NaN       NaN    NaN    NaN
# 4                                                NaN       NaN    NaN    NaN
#
#   Org_33
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['Artikel', 'Typ', 'Paragraph', 'Absatz', 'Gliederungspunkt_Nr',
#        'Gesetzestext_Entwurf_1_0307', 'Gesetzestext_Entwurf_2_1508',
#        'Gesetzestext_Entwurf_3_0110', 'Gesetzestext_Entwurf_4_0312', 'Org_2',
#        'Org_3', 'Org_5', 'Org_6', 'Org_7', 'Org_8', 'Org_9', 'Org_10',
#        'Org_11', 'Org_12', 'Org_13', 'Org_14', 'Org_15', 'Org_16', 'Org_17',
#        'Org_18', 'Org_19', 'Org_20', 'Org_21', 'Org_22', 'Org_23', 'Org_24',
#        'Org_25', 'Org_26', 'Org_27', 'Org_28', 'Org_29', 'Org_30', 'Org_31',
#        'Org_32', 'Org_33'],
#       dtype='object')

# %% [markdown]
# ## 2. Data Preparation
#
# Identify organization columns and prepare the data for analysis.

# %%
# Define metadata columns (non-organization columns)
META_COLS = [
    'Artikel',
    'Typ',
    'Paragraph',
    'Absatz',
    'Gliederungspunkt_Nr',
    'Gesetzestext_Entwurf_1_0307',
    'Gesetzestext_Entwurf_2_1508',
    'Gesetzestext_Entwurf_3_0110',
    'Gesetzestext_Entwurf_4_0312'
]


ORG_COLS = [c for c in df.columns if c not in META_COLS]
ORG_COLS[:31], len(ORG_COLS)
# Out:
# (['Org_2',
#   'Org_3',
#   'Org_5',
#   'Org_6',
#   'Org_7',
#   'Org_8',
#   'Org_9',
#   'Org_10',
#   'Org_11',
#   'Org_12',
#   'Org_13',
#   'Org_14',
#   'Org_15',
#   'Org_16',
#   'Org_17',
#   'Org_18',
#   'Org_19',
#   'Org_20',
#   'Org_21',
#   'Org_22',
#   'Org_23',
#   'Org_24',
#   'Org_25',
#   'Org_26',
#   'Org_27',
#   'Org_28',
#   'Org_29',
#   'Org_30',
#   'Org_31',
#   'Org_32',
#   'Org_33'],
#  31)

# %% [markdown]
# ## 3. Text Cleaning
#
# Apply text normalization to handle PDF artifacts and ensure consistent formatting.

# %%
import re
from typing import Optional
import numpy as np

# matches: word-<newline>word
HYPHEN_LINEBREAK_RE = re.compile(r"(\w+)-\s*\n\s*(\w+)", flags=re.UNICODE)

# optional: only if you really want to normalize slashes
SLASH_JOIN_RE = re.compile(r"(\w+)\s*/\s*(\w+)", flags=re.UNICODE)


def clean_legal_text(text: Optional[str]) -> str:
    """
    Cleans legal text while preserving semantic hyphenation.
    Only removes hyphens caused by line breaks (e.g. PDF artifacts).
    """
    if text is None or (isinstance(text, float) and np.isnan(text)):
        return ""

    t = str(text)

    # Normalize line endings
    t = t.replace("\r\n", "\n").replace("\r", "\n")

    # Normalize tabs
    t = t.replace("\t", " ")

    # Remove hyphenation ONLY when caused by line breaks
    # Example: "Ther-\nmal" -> "Thermal"
    # Keeps: "Erdwärme-Anlage", "CO2-Preis"
    t = HYPHEN_LINEBREAK_RE.sub(r"\1\2", t)

    # Replace remaining newlines with spaces
    t = re.sub(r"\n+", " ", t)

    # Normalize slashed compounds
    # Example: "Wärme-/Kältespeicher" -> "Wärme- und Kältespeicher"
    t = SLASH_JOIN_RE.sub(r"\1 und \2", t)

    # Collapse whitespace
    t = re.sub(r"\s+", " ", t).strip()

    return t

# %%
for org in ORG_COLS:
    df[org] = df[org].apply(clean_legal_text)

# %% [markdown]
# ## 4. Organization Statistics
#
# Calculate descriptive statistics for each organization's submissions.

# %%
records = []

for org in ORG_COLS:
    # Filter non-empty comments
    mask = df[org].str.strip().ne("")
    comments = df.loc[mask, org]

    n_comments = int(mask.sum())
    n_articles = df.loc[mask, "Artikel"].nunique()

    token_counts = comments.str.split().str.len()
    total_tokens = int(token_counts.sum())
    mean_tokens = float(token_counts.mean()) if n_comments > 0 else 0.0
    # Round to 2 decimal places
    mean_tokens = round(mean_tokens, 2)

    records.append({
        "organization": org,
        "n_comments": n_comments,
        "n_articles_commented": n_articles,
        "total_tokens": total_tokens,
        "mean_tokens_per_comment": mean_tokens,
    })

org_summary = pd.DataFrame(records).sort_values(
    "n_comments", ascending=False
)

org_summary.head(10)
# Out:
#    organization  n_comments  n_articles_commented  total_tokens  \
# 26       Org_29          21                     6          4417
# 9        Org_12          18                     4          5479
# 20       Org_23          16                     4          2461
# 14       Org_17          14                     3          2957
# 13       Org_16          14                     6          1476
# 11       Org_14          13                     3          1504
# 8        Org_11          13                     6           629
# 27       Org_30          12                     4          2647
# 19       Org_22          11                     5          1179
# 0         Org_2          11                     3          2114
#
#     mean_tokens_per_comment
# 26                   210.33
# 9                    304.39
# 20                   153.81
# 14                   211.21
# 13                   105.43
# 11                   115.69
# 8                     48.38
# 27                   220.58
# 19                   107.18
# 0                    192.18

# %%
# Load organization metadata from secondary sheet
org_map = pd.read_excel(EXCEL_PATH, sheet_name="Org_Map")

org_summary = org_summary.merge(
    org_map, how="left", left_on="organization", right_on="Org_ID"
)

# %%
# Select and reorder columns for final output
org_summary = org_summary[
    ["Organisation_Name", "Organisation_Typ",
     "n_comments", "n_articles_commented",
     "total_tokens", "mean_tokens_per_comment"]
]
org_summary
# Out:
#                                     Organisation_Name    Organisation_Typ  \
# 0                                                BDEW  Wirtschaftsverband
# 1                 Verband kommunaler Unternehmen e.V.  Wirtschaftsverband
# 2   Ministerium für Wirtschaft, Industrie, Klimasc...  Land/Landesbehörde
# 3                      Bundesverband Geothermie e. V.  Wirtschaftsverband
# 4   Bundesverband Erdgas, Erdöl und Geoenergie e.V...  Wirtschaftsverband
# 5   Bund für Umwelt und Naturschutz Deutschland e....      Umweltverband
# 6   Niedersächsisches Ministerium für Wirtschaft, ...  Land/Landesbehörde
# 7    Bundesvereinigung der kommunalen Spitzenverbände     Kommunalverband
# 8   Ministerium für Energiewende, Klimaschutz, Umw...  Land/Landesbehörde
# 9                           Deutsche Umwelthilfe e.V.      Umweltverband
# 10  Thüringer Ministerium für Umwelt, Energie, Nat...  Land/Landesbehörde
# 11            NABU (Naturschutzbund Deutschland) e.V.      Umweltverband
# 12  AGFW | Der Energieeffizienzverband für Wärme, ...  Wirtschaftsverband
# 13                                           8KU GmbH         Unternehmen
# 14                            Stadtwerke München GmbH         Unternehmen
# 15  Ministerium für Wirtschaft, Infrastruktur, Tou...  Land/Landesbehörde
# 16                                               DIHK  Wirtschaftsverband
# 17                         Oberbergamt des Saarlandes  Land/Landesbehörde
# 18  Ministerium für Klimaschutz, Landwirtschaft, l...  Land/Landesbehörde
# 19             Bundesverband Erneuerbare Energie e.V.  Wirtschaftsverband
# 20                     Vulcan Energie Ressourcen GmbH         Unternehmen
# 21                         Kunststoffrohrverband e.V.  Wirtschaftsverband
# 22                                       ISOPLUS GmbH         Unternehmen
# 23  Bundesverband Deutscher Wasserkraftwerke (BDW)...  Wirtschaftsverband
# 24  Ministerium für Wissenschaft, Energie, Klimasc...  Land/Landesbehörde
# 25  Verband der industriellen Energie- und Kraftwi...  Wirtschaftsverband
# 26  DVGW - Deutscher Verein des Gas- und Wasserfac...              Andere
# 27                          Hauptstadtbüro Bioenergie  Wirtschaftsverband
# 28                      Bundesverband Wärmepumpe e.V.  Wirtschaftsverband
# 29                Verband der Kali- und Salzindustrie  Wirtschaftsverband
# 30    BVES Bundesverband Energiespeicher Systeme e.V.  Wirtschaftsverband
#
#     n_comments  n_articles_commented  total_tokens  mean_tokens_per_comment
# 0           21                     6          4417                   210.33
# 1           18                     4          5479                   304.39
# 2           16                     4          2461                   153.81
# 3           14                     3          2957                   211.21
# 4           14                     6          1476                   105.43
# 5           13                     3          1504                   115.69
# 6           13                     6           629                    48.38
# 7           12                     4          2647                   220.58
# 8           11                     5          1179                   107.18
# 9           11                     3          2114                   192.18
# 10          10                     3            30                     3.00
# 11          10                     3          1014                   101.40
# 12          10                     3           664                    66.40
# 13           9                     3           918                   102.00
# 14           9                     4          2222                   246.89
# 15           8                     3          1280                   160.00
# 16           6                     3           974                   162.33
# 17           6                     1            69                    11.50
# 18           5                     2           288                    57.60
# 19           4                     2           528                   132.00
# 20           4                     3           615                   153.75
# 21           3                     2           151                    50.33
# 22           3                     1          1788                   596.00
# 23           3                     2           334                   111.33
# 24           2                     2            85                    42.50
# 25           2                     2           154                    77.00
# 26           2                     2           785                   392.50
# 27           1                     1           263                   263.00
# 28           1                     1           159                   159.00
# 29           1                     1           193                   193.00
# 30           0                     0             0                     0.00

# %%
# Calculate maximum token count across all comments
max_tokens = 0
for org in ORG_COLS:
    token_counts = df[org].str.split().str.len()
    org_max = token_counts.max()
    if org_max > max_tokens:
        max_tokens = org_max

max_tokens
# Out:
# np.int64(856)
